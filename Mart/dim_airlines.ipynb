# %%
# %sql
create or replace table projectdev.mart.dim_airlines
using delta
location 'abfss://mart@datalakestrgdev.dfs.core.windows.net/airlines'
as
select * from projectdev.cleansed.airlines

# %%
# %sql
select * from projectdev.mart.dim_airlines
