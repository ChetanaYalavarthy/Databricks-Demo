# %%
# %sql
create or replace table projectdev.mart.dim_unique_carriers
using delta
location 'abfss://mart@datalakestrgdev.dfs.core.windows.net/unique_carriers'
as
select * from projectdev.cleansed.unique_carriers

# %%
# %sql
select * from projectdev.mart.dim_unique_carriers
