# %%
# %sql
create or replace table projectdev.mart.dim_cancellation
using delta
location 'abfss://mart@datalakestrgdev.dfs.core.windows.net/cancellation'
as
select * from projectdev.cleansed.cancellation

# %%
# %sql
select * from projectdev.mart.dim_cancellation

# %%
# %sql
describe history projectdev.mart.dim_cancellation
