# %%
# %sql
create or replace table projectdev.mart.dim_airport
using delta
location 'abfss://mart@datalakestrgdev.dfs.core.windows.net/airport'
as
select * from projectdev.cleansed.airport

# %%
# %sql
select * from projectdev.mart.dim_airport
