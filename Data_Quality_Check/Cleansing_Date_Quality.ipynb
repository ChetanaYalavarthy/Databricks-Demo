# %%
# %run /Workspace/utilities

# %%
list_table_info = [
    ("STREAMING UPDATE", "plane", 100),
    ("STREAMING UPDATE", "airport", 200),
    ("STREAMING UPDATE", "cancellation", 100),
    ("STREAMING UPDATE", "unique_carriers", 500),
    ("WRITE", "airlines", 10),
]
for i in list_table_info:
    # remove_duplicates(database,table_name)
    count_check("projectdev","cleansed", i[0], i[1], i[2])
