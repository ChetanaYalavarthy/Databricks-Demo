# %%
# %run /Workspace/utilities

# %%
insert_query = "select count(*) from mart.dim_unique_carriers group by Code having count(*) >1"
insert_test_cases('mart',1,'Check if the Code is duplicated or not in dim_unique_carriers',insert_query,0)

# %%
insert_query = "select count(*) from mart.dim_airport group by Code having count(*) >1"
insert_test_cases('mart',2,'Check if the Code is duplicated or not in dim_airport',insert_query,0)
